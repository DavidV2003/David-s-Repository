# %% [markdown]
# <a href="https://colab.research.google.com/github/yakuoku/David-s-Repository/blob/main/Ejercicios_1_resueltos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejericicio 1
# Creen un vector a entre 5 y 6 con intervalo de 0.2 y guardenlo en formato ```datos.npy``` y luego carguenlo con nombre b y muestrelo

# %%
a=np.arange(5,6.02,0.2)
np.save('datos.npy', a)
b=np.load('datos.npy')
print(b)
# Out:
# [5.  5.2 5.4 5.6 5.8 6. ]

# %% [markdown]
# ## Ejercicio 2
#
# Cree un una matriz A con ```np.array```
#
# $$\begin{bmatrix}
# 	1 & 3 & 5 \\
# 	11 & 9 & 7\\
# 	13 & 15 & 17 \\
# 	\end{bmatrix}$$
#
# Luego de eso utilize el metodo ```np.sort``` con  el argumento ```axis =1``` or ```axis=0```
#
# A que conclusiones llegan?

# %%
a=np.array([[1,3,5],[11,9,7],[13,15,17]])
print(a)
print("--------------------")
b=np.sort(a,axis=0)
print(b)
print("--------------------")
c=np.sort(a,axis=1)
print(c)
print("--------------------")
d=np.sort(a,axis=None)
print(d)
print("--------------------")
e=np.sort(a,axis=-1)
print(e)
# Out:
# [[ 1  3  5]
#  [11  9  7]
#  [13 15 17]]
# --------------------
# [[ 1  3  5]
#  [11  9  7]
#  [13 15 17]]
# --------------------
# [[ 1  3  5]
#  [ 7  9 11]
#  [13 15 17]]
# --------------------
# [ 1  3  5  7  9 11 13 15 17]
# --------------------
# [[ 1  3  5]
#  [ 7  9 11]
#  [13 15 17]]

# %% [markdown]
# ## Ejercicio 3
#
# Cree una matriz de 3x3 B, como la siguiente:
#
# $$\begin{bmatrix}
# 	9 & 1 & 2 \\
# 	1 & 9 & 5\\
# 	2 & 5 & 9 \\
# 	\end{bmatrix}$$
#
# 1. Convierta la matriz a un vector de 1x9
# 2. Ordene de de menor a mayor el vector
# 3. Aplique un filtro para extraer solo los numeros menores que 9

# %%
a=np.array([[9,1,2],[1,9,5],[2,5,9]])
print(a)
print("--------------------")
b=np.sort(a,axis=None)
print(b)
print("--------------------")
c=(np.extract(b<9,b))
print(c)
# Out:
# [[9 1 2]
#  [1 9 5]
#  [2 5 9]]
# --------------------
# [1 1 2 2 5 5 9 9 9]
# --------------------
# [1 1 2 2 5 5]

# %% [markdown]
# ## Ejercicio 4
#
# Cree una matriz de 3x3 C, como la siguiente:
#
# $$\begin{bmatrix}
# 	1 & 4 & 7 \\
# 	2 & 5 & 8\\
# 	3 & 6 & 9 \\
# 	\end{bmatrix}$$
#
# 1. Calcule la media por cada columna
# 2. Calcule la media por cada fila
# 3. Obtenga la media por columnas dandole el doble de peso a la columna con mayores valores de la variable
# 4. Calcule el percentil 25 por cada columna

# %%
a=np.array([[1,4,7],[2,5,8],[3,6,9]])
print(a)
print("-----------------------")
print(np.average(a,axis=0))
print("columna")
print("-----------------------")
print(np.average(a,axis=1))
print("Fila")
print("-----------------------")
print(np.average(a,axis=0, weights=(1,1,2)))
print("-----------------------")
print(np.percentile(a,25,axis=0))
print("Percentil")
# Out:
# [[1 4 7]
#  [2 5 8]
#  [3 6 9]]
# -----------------------
# [2. 5. 8.]
# columna
# -----------------------
# [4. 5. 6.]
# Fila
# -----------------------
# [2.25 5.25 8.25]
# -----------------------
# [1.5 4.5 7.5]
# Percentil

# %% [markdown]
# ## Ejercicio 5
#
# Carguen la imagen data_science que se encuentra en el siguiente link: [texto del enlace](https://drive.google.com/file/d/1LoGybQ8t9g6orVp8Wh0uqU7BXY0kCzlh/view?usp=sharing) en la semana 1 del Bootcamp y realicen los siguientes procedimientos
#
# 1. Muestrar la imagen tal como viene
# 2. Averiguen que es un pixel y determinen cuantos pixeles tiene la imagen
# 3. Recortar la imagen donde solo aparezca la palabra DATA
# 4. Convertir la imagen a matriz y aplicar la funcion coseno
# 5. Reemplazar los valores menores que 100 en la imagen original por 180 y graficar ¿Que observan, que modificaciones ocurrieron y porque?. **Sugerencia:** *Busquen acerca de que es la escala RGB y seguro comprenderan mejor*

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/Bootcamp/Semana 1'
# Out:
# /content/gdrive/MyDrive/Bootcamp/Semana 1

# %%
from skimage import io

# %%
photo = io.imread('data_science.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Primero
plt.imshow(photo)

# %%
#Segundo
photo.size
# Out:
# 2942280

# %%
#Tercero
plt.imshow(photo[180:350, 150:620]) # Recortar

# %%
#Cuarto
import numpy as np
photo_cos = np.cos(photo) 
photo_cos
# Out:
# array([[[-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         ...,
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949]],
#
#        [[-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         ...,
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949]],
#
#        [[-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         ...,
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949]],
#
#        ...,
#
#        [[-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         ...,
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949]],
#
#        [[-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         ...,
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949]],
#
#        [[-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         ...,
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949],
#         [-0.858 ,  0.2323, -0.4949]]], dtype=float16)

# %%
#Quinto
photo_mask=np.where(photo>100,180,photo)
plt.imshow(photo_mask)
